# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
matplotlib.use('TkAgg')  # O 'Qt5Agg', 'GTK3Agg', etc.
import matplotlib.pyplot as plt

url_varPrincipales = "https://api.bcra.gob.ar/estadisticas/v2.0/PrincipalesVariables"
url_base = "https://api.bcra.gob.ar/estadisticas/v2.0/DatosVariable"

# URL de la API

url_CER = f'{url_base}/30/2023-05-01/2023-06-01'
url_UVA = f'{url_base}/31/2023-05-31/2024-05-31'


class create_graphic:

    def proccess(self, url):
        data = self.request2df(url)
        self.graphic(data)

    def request2df(self, url):
        response = requests.get(url, verify=False)

        # Verificar que la solicitud fue exitosa
        if response.status_code == 200:
            data = response.json()
            data_normalize = pd.json_normalize(data, record_path='results')
            print(data_normalize)

            return data_normalize

        else:
            print(f"Error en la solicitud: {response.status_code}")

    def graphic(self, data):
        #   Ejemplo de gráfico de línea
        plt.figure(figsize=(10, 6))
        sns.lineplot(data=data, x='fecha', y='valor')
        plt.title('UVA 31-05-2023 a 31-05-2024')
        plt.xlabel('Fecha')
        plt.xticks(rotation=45)
        plt.ylabel('Valor')
        plt.show()

req = create_graphic()
req.proccess(url_varPrincipales)
# Out:
# /home/juancr/Proyectos/APIBCRA/APIBCRA/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.bcra.gob.ar'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
#     idVariable  cdSerie                                        descripcion  \
# 0            1      246  Reservas Internacionales del BCRA (en millones...
# 1            4     7927  Tipo de Cambio Minorista ($ por USD) Comunicac...
# 2            5      272  Tipo de Cambio Mayorista ($ por USD) Comunicac...
# 3            6     7935             Tasa de Política Monetaria (en % n.a.)
# 4            7     1222     BADLAR en pesos de bancos privados (en % n.a.)
# 5            8     7922       TM20 en pesos de bancos privados (en % n.a.)
# 6            9     7920  Tasas de interés de las operaciones de pase ac...
# 7           10     7921  Tasas de interés de las operaciones de pase pa...
# 8           11     3139  Tasas de interés por préstamos entre entidades...
# 9           12     1212  Tasas de interés por depósitos a 30 días de pl...
# 10          13     7924  Tasa de interés de préstamos por adelantos en ...
# 11          14     7925            Tasa de interés de préstamos personales
# 12          15      250      Base monetaria - Total (en millones de pesos)
# 13          16      251       Circulación monetaria (en millones de pesos)
# 14          17      251  Billetes y monedas en poder del público (en mi...
# 15          18      296  Efectivo en entidades financieras (en millones...
# 16          19      252  Depósitos de los bancos en cta. cte. en pesos ...
# 17          21      444  Depósitos en efectivo en las entidades financi...
# 18          22      446  En cuentas corrientes (neto de utilización FUC...
# 19          23      450          En Caja de ahorros (en millones de pesos)
# 20          24      452  A plazo (incluye inversiones y excluye CEDROS)...
# 21          25     7919  M2 privado, promedio móvil de 30 días, variaci...
# 22          26      392  Préstamos de las entidades financieras al sect...
# 23          27     7931                 Inflación mensual (variación en %)
# 24          28     7932         Inflación interanual (variación en % i.a.)
# 25          29     7933  Inflación esperada - REM próximos 12 meses - M...
# 26          30     3540                              CER (Base 2.2.2002=1)
# 27          31     7913  Unidad de Valor Adquisitivo (UVA) (en pesos -c...
# 28          32     7914  Unidad de Vivienda (UVI) (en pesos -con dos de...
# 29          34     7936             Tasa de Política Monetaria (en % e.a.)
# 30          35     7937     BADLAR en pesos de bancos privados (en % e.a.)
# 31          40     7988  Índice para Contratos de Locación (ICL-Ley 27....
# 32          41     7990  Tasas de interés de las operaciones de pase pa...
# 33          42      266  Pases pasivos para el BCRA - Saldos (en millon...
#
#          fecha         valor
# 0   2024-06-03  2.913400e+04
# 1   2024-06-05  9.381400e+02
# 2   2024-06-05  8.982500e+02
# 3   2024-06-05  4.000000e+01
# 4   2024-06-04  3.237500e+01
# 5   2024-06-04  3.318750e+01
# 6   2024-06-05  6.000000e+01
# 7   2024-06-05  4.000000e+01
# 8   2024-06-04  4.038000e+01
# 9   2024-06-04  3.085000e+01
# 10  2024-06-04  4.476000e+01
# 11  2024-06-04  6.588000e+01
# 12  2024-06-03  1.670185e+07
# 13  2024-06-03  1.031919e+07
# 14  2024-06-03  9.223352e+06
# 15  2024-06-03  1.095842e+06
# 16  2024-06-03  6.382658e+06
# 17  2024-06-03  9.094364e+07
# 18  2024-06-03  1.893297e+07
# 19  2024-06-03  3.230969e+07
# 20  2024-06-03  3.438824e+07
# 21  2024-06-03  1.624000e+02
# 22  2024-06-03  3.030348e+07
# 23  2024-04-30  8.800000e+00
# 24  2024-04-30  2.894000e+02
# 25  2024-04-30  8.800000e+01
# 26  2024-06-05  3.947291e+02
# 27  2024-06-05  9.941100e+02
# 28  2024-06-05  7.466600e+02
# 29  2024-06-05  4.915000e+01
# 30  2024-06-04  3.761000e+01
# 31  2024-06-05  1.417000e+01
# 32  2024-06-05  4.915000e+01
# 33  2024-06-03  1.890825e+07

# %%
        # Ejemplo de gráfico de barras
        plt.figure(figsize=(10, 6))
        sns.barplot(data=data, x='fecha', y='valor')
        plt.title('UVA 31-05-2023 a 31-05-2024')
        plt.xlabel('Fecha')
        plt.xticks(rotation=45)
        plt.ylabel('Valor')
        plt.show()
